# %% [markdown]
# ## Preparation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = "/content/drive/MyDrive/ColabNotebooks/DD2360/hw3_1"
os.chdir(path)
# !ls
# Out:
# ex_1	 ex_2	  ex_3	   try	   vectorAdd
# ex_1.cu  ex_2.cu  ex_3.cu  try.cu  vectorAdd.cu

# %% [markdown]
# ## Compiling and Execution

# %%
# !nvcc -arch=sm_75 ex_3.cu -o ex_3

# %%
# !./ex_3 10000000

# %%
# !./ex_3 100000

# %% [markdown]
# ## Plot a histogram

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("ex_3.csv", header=None, names=['x'])
plt.title('Histogram')

N = 4096
plt.xlabel('index')
ind = np.arange(N)  
plt.bar(ind, df['x'])
plt.figure(figsize=(10, 600))
plt.show()

# %% [markdown]
# ## NVIDIA Nsight Systems for Profiling

# %%
# !/usr/local/cuda-11/bin/nv-nsight-cu-cli ./ex_3 1024
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:1, device:1
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:1, device:1
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:1, device:1
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:2, device:2
# Equal!
# host:0, device:0
# Equal!
# host:1, device:1
# Equal!
# host:0, device:0
# Equal!
# host:2, device:2
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:1, device:1
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# Equal!
# host:0, device:0
# ...
